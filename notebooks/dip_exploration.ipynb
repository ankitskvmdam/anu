# %%
import os
from pprint import pprint
import vaex
import pandas as pd
from anu.parser import Mif25Parser

# %%
# Data location
data_loc = "../data/raw/test.mif25"

# %%
# Parser
parser = Mif25Parser()
parser.parse(data_loc)

# %%
# File dictionary created by parser
parser.file_dict
# Out:
# {'interactor_id': ['445',
#   '559',
#   '617',
#   '1025',
#   '1026',
#   '19',
#   '25',
#   '343',
#   '80',
#   '493',
#   '147',
#   '472',
#   '582',
#   '551',
#   '548',
#   '1078',
#   '51',
#   '637',
#   '40',
#   '721',
#   '723',
#   '189',
#   '199',
#   '18',
#   '780',
#   '119',
#   '480',
#   '743',
#   '1048',
#   '425',
#   '704',
#   '1104',
#   '671',
#   '400',
#   '391',
#   '53',
#   '953',
#   '169',
#   '239',
#   '262',
#   '48',
#   '636',
#   '356',
#   '187',
#   '1074',
#   '368',
#   '150',
#   '257',
#   '952',
#   '331',
#   '74',
#   '327',
#   '163',
#   '713',
#   '681',
#   '497',
#   '153',
#   '768',
#   '1042',
#   '182',
#   '785',
#   '372',
#   '383',
#   '674',
#   '538',
#   '459',
#   '155',
#   '752',
#   '62',
#   '908',
#   '13',
#   '142',
#   '962',
#   '760',
#   '541',
#   '311',
#   '90',
#   '1030',
#   '1084',
#   '1081',
#   '1065',
#   '4',
#   '58',
#   '339',
#   '508',
#   '539',
#   '1043',
#   '232',
#   '250',
#   '1016',
#   '244',
#   '696',
#   '665',
#   '31',
#   '285'],
#  'short_label': ['Cdkn1b',
#   '',
#   'CD4',
#   'carB',
#   'carA',
#   'dpp',
#   'CDC16',
#   'TAF2',
#   'Tbp',
#   'Taf6',
#   'TAF1',
#   'JARID1A',
#   'RB1',
#   'BCY1',
#   'Tpk1p',
#   'TBP',
#   'POU2F2',
#   'h',
#   'gro',
#   'HLHmbeta',
#   'HLHmgamma',
#   'CBL',
#   'CRK',
#   'SNF1',
#   'Sip3p',
#   'PIK3R1',
#   'INSR',
#   'YWHAB',
#   'RAF1',
#   'RBL2',
#   'MYOD1',
#   'Ilv2p',
#   'ILV6',
#   '',
#   'CXCL12',
#   'Hmga1',
#   'SPI1',
#   'SSRP1',
#   'e(y)1',
#   'CKB2',
#   'CKA1',
#   'ase',
#   'HLHm3',
#   'ac',
#   '',
#   'TP53',
#   'YY1',
#   'EP300',
#   'CREBBP',
#   'SREBP-1',
#   'TCF3',
#   'LMX1A',
#   'TCF4',
#   'ID3',
#   'RPD3',
#   'CDC28',
#   'mlkA',
#   'ATMPK3',
#   'ABL1',
#   'ATM',
#   'Gdi1p',
#   'RAB4A',
#   'ACTN2',
#   'Grin1',
#   'CALM',
#   'PPP2R5A',
#   'TLX1',
#   'FFC',
#   'petA',
#   '',
#   'PHO2',
#   'BAS1',
#   'SOL1',
#   'LOS1',
#   'DNASE1',
#   'Actin',
#   'LBP',
#   'CD14',
#   'Gfap',
#   'PRNP',
#   'Bcl2',
#   'Prnp',
#   'HSPD1',
#   'groL',
#   'malE',
#   'malG',
#   'BCL2',
#   'BAX',
#   'ced-9',
#   'ced-4',
#   'ced-3',
#   'Cyc8p',
#   'MIG1',
#   'CCL5',
#   'TRADD'],
#  'fullname': ['cyclin-cdk inhibitor p27',
#   'cell division cycle-2-related protein kinase  ERK1',
#   'T-cell surface glycoprotein CD4 precursor',
#   'Carbamoyl-phosphate synthase large chain (Carbamoyl-phosphate synthetase ammonia chain)',
#   'Carbamoyl-phosphate synthase small chain (Carbamoyl-phosphate synthetase glutamine chain)',
#   'decapentaplegic protein precursor',
#   'Anaphase-promoting complex subunit CDC16',
#   'Transcription initiation factor TFIID subunit 2',
#   'TATA-box-binding protein',
#   'transcription factor IID chain',
#   'transcription initiation factor IID 250K chain splice form 1',
#   'retinoblastoma binding protein 2',
#   'Retinoblastoma-associated protein',
#   'protein kinase , cAMP-dependent, regulatory chain',
#   'protein kinase , cAMP-dependent, catalytic chain 1',
#   'TATA-box-binding protein',
#   'transcription factor Oct-2',
#   'segmentation protein hairy',
#   'enhancer of split protein',
#   'helix-loop-helix protein m-beta',
#   'helix-loop-helix protein m-gamma',
#   'transforming protein (cbl)',
#   'Proto-oncogene C-crk',
#   'Carbon catabolite-derepressing protein kinase',
#   'SIP3 protein',
#   'Phosphatidylinositol 3-kinase regulatory subunit alpha',
#   'Insulin receptor',
#   '14-3-3 protein beta/alpha',
#   'RAF proto-oncogene serine/threonine-protein kinase',
#   'Retinoblastoma-like protein 2',
#   'Myoblast determination protein 1',
#   'acetolactate synthase',
#   'Acetolactate synthase small subunit, mitochondrial precursor',
#   'CC chemokine receptor 5',
#   'cytokine SDF-1-beta',
#   'nonhistone chromosomal protein HMG-I(Y)',
#   'PU.1 transcription factor',
#   'FACT complex subunit SSRP1',
#   'Transcription initiation factor TFIID subunit 9',
#   'casein kinase II - alpha chain',
#   'Casein kinase II subunit alpha',
#   'achaete-scute locus protein ase',
#   'enhancer of split locus protein m3',
#   'Achaete-scute complex protein T5',
#   'large T antigen',
#   'Cellular tumor antigen p53',
#   'Transcriptional repressor protein YY1',
#   'Histone acetyltransferase p300',
#   'CREB-binding protein',
#   'Sterol regulatory element 1 binding protein, SREBP-1',
#   'Transcription factor E2-alpha',
#   'transcription factor lmx-1',
#   'transcription factor ITF-2',
#   'helix-loop-helix protein ID3',
#   'Histone deacetylase RPD3',
#   'protein kinase  cdc28',
#   'myosin-light-chain kinase  A',
#   'mitogen-activated protein kinase 3',
#   'Proto-oncogene tyrosine-protein kinase ABL1',
#   'ataxia telangiectasia-associated protein',
#   'GDP dissociation inhibitor GDI1',
#   'GTP-binding protein Rab4',
#   'alpha-actinin 2',
#   'N-methyl-D-aspartate receptor chain NMDA-R1A',
#   'calmodulin',
#   'gene PP2A protein',
#   'homeotic protein Hox 11',
#   'signal recognition particle 54CP protein precursor',
#   'Cytochrome f',
#   'telomerase component p80',
#   'Regulatory protein PHO2',
#   'Transcription factor BAS1',
#   '6-phosphogluconolactonase 1',
#   'pre-tRNA splicing protein LOS1',
#   'Deoxyribonuclease I precursor',
#   'actin, skeletal muscle',
#   'lipopolysaccharide-binding protein',
#   'monocyte surface glycoprotein CD14 precursor',
#   'glial fibrillary acidic protein, astrocyte',
#   'major prion PrP-Sc protein precursor',
#   'transforming protein bcl-2-alpha',
#   'Major prion protein',
#   '60 kDa heat shock protein, mitochondrial precursor',
#   '60 kDa chaperonin',
#   'Maltose-binding periplasmic protein precursor (Maltodextrin-binding protein) (MMBP)',
#   'Maltose transport system permease protein malG',
#   'Apoptosis regulator Bcl-2',
#   'Apoptosis regulator BAX',
#   'apoptosis suppressor CED-9',
#   'cell death protein ced-4',
#   'interleukin-1 beta-converting enzyme homolog CED-3',
#   'CYC8 protein',
#   'regulatory protein MIG1',
#   'monocyte chemoattractant cytokine RANTES precursor',
#   'Tumor necrosis factor receptor type 1-associated DEATH domain protein'],
#  'xref': [[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-445N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P46414', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '12576', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-559N', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-617N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_000607', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P01730', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '920', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1025N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_414574', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P00968', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '944775', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1026N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_285726', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P00907', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '949025', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-19N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_477311', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P07713', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '33432', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-25N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_012903', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P09798', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '853846', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-343N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_009971', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P23255', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '850409', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-80N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_523805', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P20227', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '37476', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-493N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q62311', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '21343', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-147N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P21675', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6872', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-472N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_005047', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P29375', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5927', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-582N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_000312', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P06400', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5925', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-551N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_012231', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P07278', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '854778', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-548N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_012371', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P06244', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '853275', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1078N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_003185', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P20226', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6908', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-51N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P09086', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5452', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-637N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_523977', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P14003', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '38995', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-40N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_733133', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P16371', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '43162', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-721N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_524505', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q01069', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '43152', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-723N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_524504', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q01070', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '43151', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-189N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_005179', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P22681', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '867', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-199N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'refseq', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P46108', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '1398', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-18N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_010765', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P06782', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '852088', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-780N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_014142', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P38717', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '855464', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-119N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P27986', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5295', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-480N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P06213', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '3643', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-743N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P31946', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '7529', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1048N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_002871', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P04049', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5894', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-425N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_005602', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q08999', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5934', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-704N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_002469', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P15172', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '4654', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1104N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_013826', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P07342', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '855135', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-671N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_009918', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P25605', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '850348', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-400N', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-391N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P48061', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6387', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-53N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_057869', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P17095', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '15361', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-953N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_003111', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P17947', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6688', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-169N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_003137', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q08945', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6749', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-239N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_523391', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q27272', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '32762', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-262N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_014682', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P38930', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '854204', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-48N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_012229', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P15790', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '854776', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-636N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_476694', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P09775', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '30985', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-356N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_524509', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q01068', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '43156', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-187N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_476824', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P10083', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '30981', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1074N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q9DH70', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '1489531', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-368N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P04637', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '7157', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-150N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_003394', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P25490', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '7528', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-257N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_001420', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q09472', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '2033', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-952N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_004371', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q92793', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '1387', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-331N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P36956', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6720', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-74N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P15923', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6929', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-327N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q04650', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-163N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_003190', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P15884', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6925', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-713N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_002158', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q02535', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '3399', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-681N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_014069', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P32561', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '855386', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-497N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P43063', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-153N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P25323', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '8622308', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-768N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_190150', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q39023', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '823706', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1042N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P00519', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '25', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-182N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q13315', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '472', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-785N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_011062', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P39958', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '856876', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-372N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P20338', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5867', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-383N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_001094', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P35609', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '88', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-674N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_058706', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P35439', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '24408', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-538N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_001734', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P02593', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '805', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-459N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_006234', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q15172', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '5525', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-155N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P31314', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '3195', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-752N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_196014', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P37107', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '830273', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-62N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P36438', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-908N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q94818', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-13N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_010177', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P07269', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '851452', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-142N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_013025', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P22035', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '853974', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-962N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_014432', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P50278', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '855769', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-760N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_012717', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P33418', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '853630', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-541N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_776959', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P00639', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '282217', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-311N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P02568', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-90N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P18428', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '3929', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1030N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_000582', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P08571', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '929', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1084N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P03995', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '14580', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1081N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P04273', 'refType': 'identity', 'refTypeAc': 'MI:0356'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1065N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_033871', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P10417', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '12043', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-4N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_035300', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P04925', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '19122', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-58N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P10809', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '3329', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-339N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_313151', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P0A6F5', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '948665', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-508N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_290668', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P02928', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '948538', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-539N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_290666', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P07622', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '948530', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1043N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_000624', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P10415', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '596', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-232N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q07812', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '581', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-250N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_499284', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P41958', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '3565776', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-1016N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_498007', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P30429', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '175643', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-244N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_502538', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P42573', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '178272', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-696N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_009670', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P14922', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '852410', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-665N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_011480', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P27705', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '852848', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-31N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_002976', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P13501', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '6352', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}],
#   [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-285N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'refseq', 'dbAc': 'MI:0481', 'id': 'NP_003780', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'Q15628', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#    {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '8717', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}]],
#  'interactor_type_fullname': ['protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein',
#   'protein'],
#  'interactor_type_short_label': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  'interactor_type_xref': [[{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}],
#   [{'refTypeAc': 'MI:0356', 'refType': 'identity', 'id': 'MI:0326', 'dbAc': 'MI:0488', 'db': 'psi-mi'}]],
#  'organism_ncbi_tax_id': ['10090',
#   '10090',
#   '9606',
#   '83333',
#   '83333',
#   '7227',
#   '4932',
#   '4932',
#   '7227',
#   '10090',
#   '9606',
#   '9606',
#   '9606',
#   '4932',
#   '4932',
#   '9606',
#   '9606',
#   '7227',
#   '7227',
#   '7227',
#   '7227',
#   '9606',
#   '9606',
#   '4932',
#   '4932',
#   '9606',
#   '9606',
#   '9606',
#   '9606',
#   '9606',
#   '9606',
#   '4932',
#   '4932',
#   '9606',
#   '9606',
#   '10090',
#   '9606',
#   '9606',
#   '7227',
#   '4932',
#   '4932',
#   '7227',
#   '7227',
#   '7227',
#   '10633',
#   '9606',
#   '9606',
#   '9606',
#   '9606',
#   '9606',
#   '9606',
#   '10036',
#   '9606',
#   '9606',
#   '4932',
#   '5476',
#   '44689',
#   '3702',
#   '9606',
#   '9606',
#   '4932',
#   '9606',
#   '9606',
#   '10116',
#   '9606',
#   '9606',
#   '9606',
#   '3702',
#   '3711',
#   '5911',
#   '4932',
#   '4932',
#   '4932',
#   '4932',
#   '9913',
#   '9986',
#   '9606',
#   '9606',
#   '10090',
#   '10036',
#   '10090',
#   '10090',
#   '9606',
#   '83333',
#   '83333',
#   '83333',
#   '9606',
#   '9606',
#   '6239',
#   '6239',
#   '6239',
#   '4932',
#   '4932',
#   '9606',
#   '9606'],
#  'organism_short_label': ['Mus musculus',
#   'Mus musculus',
#   'Homo sapiens',
#   'Escherichia coli K12',
#   'Escherichia coli K12',
#   'Drosophila melanogaster',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Drosophila melanogaster',
#   'Mus musculus',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Drosophila melanogaster',
#   'Drosophila melanogaster',
#   'Drosophila melanogaster',
#   'Drosophila melanogaster',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Mus musculus',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Drosophila melanogaster',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Drosophila melanogaster',
#   'Drosophila melanogaster',
#   'Drosophila melanogaster',
#   'Simian virus 40',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Mesocricetus auratus',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Saccharomyces cerevisiae',
#   'Candida albicans',
#   'Dictyostelium discoideum',
#   'Arabidopsis thaliana',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Saccharomyces cerevisiae',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Rattus norvegicus',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Arabidopsis thaliana',
#   'Brassica rapa',
#   'Tetrahymena thermophila',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Bos taurus',
#   'Oryctolagus cuniculus',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Mus musculus',
#   'Mesocricetus auratus',
#   'Mus musculus',
#   'Mus musculus',
#   'Homo sapiens',
#   'Escherichia coli K12',
#   'Escherichia coli K12',
#   'Escherichia coli K12',
#   'Homo sapiens',
#   'Homo sapiens',
#   'Caenorhabditis elegans',
#   'Caenorhabditis elegans',
#   'Caenorhabditis elegans',
#   'Saccharomyces cerevisiae',
#   'Saccharomyces cerevisiae',
#   'Homo sapiens',
#   'Homo sapiens'],
#  'organism_fullname': ['house mouse',
#   'house mouse',
#   'Human',
#   '',
#   '',
#   'fruit fly',
#   "baker's yeast",
#   "baker's yeast",
#   'fruit fly',
#   'house mouse',
#   'Human',
#   'Human',
#   'Human',
#   "baker's yeast",
#   "baker's yeast",
#   'Human',
#   'Human',
#   'fruit fly',
#   'fruit fly',
#   'fruit fly',
#   'fruit fly',
#   'Human',
#   'Human',
#   "baker's yeast",
#   "baker's yeast",
#   'Human',
#   'Human',
#   'Human',
#   'Human',
#   'Human',
#   'Human',
#   "baker's yeast",
#   "baker's yeast",
#   'Human',
#   'Human',
#   'house mouse',
#   'Human',
#   'Human',
#   'fruit fly',
#   "baker's yeast",
#   "baker's yeast",
#   'fruit fly',
#   'fruit fly',
#   'fruit fly',
#   '',
#   'Human',
#   'Human',
#   'Human',
#   'Human',
#   'Human',
#   'Human',
#   'golden hamster',
#   'Human',
#   'Human',
#   "baker's yeast",
#   '',
#   '',
#   'thale cress',
#   'Human',
#   'Human',
#   "baker's yeast",
#   'Human',
#   'Human',
#   'Norway rat',
#   'Human',
#   'Human',
#   'Human',
#   'thale cress',
#   '',
#   '',
#   "baker's yeast",
#   "baker's yeast",
#   "baker's yeast",
#   "baker's yeast",
#   'cow',
#   'rabbit',
#   'Human',
#   'Human',
#   'house mouse',
#   'golden hamster',
#   'house mouse',
#   'house mouse',
#   'Human',
#   '',
#   '',
#   '',
#   'Human',
#   'Human',
#   '',
#   '',
#   '',
#   "baker's yeast",
#   "baker's yeast",
#   'Human',
#   'Human']}

# %%
panda_df = pd.DataFrame(data = parser.file_dict)
panda_df
# Out:
#       interactor_id short_label  \
# 0               445      Cdkn1b
# 1               559
# 2               617         CD4
# 3              1025        carB
# 4              1026        carA
# ...             ...         ...
# 28863         62106      KlCog7
# 28864         62105      KlCog6
# 28865         62104      KlCog5
# 28866         47802       Ptpn6
# 28867         62112  Allergin-1
#
#                                                 fullname  \
# 0                               cyclin-cdk inhibitor p27
# 1      cell division cycle-2-related protein kinase  ...
# 2              T-cell surface glycoprotein CD4 precursor
# 3      Carbamoyl-phosphate synthase large chain (Carb...
# 4      Carbamoyl-phosphate synthase small chain (Carb...
# ...                                                  ...
# 28863                                       KLLA0A08888p
# 28864       Conserved oligomeric Golgi complex subunit 6
# 28865                                       KLLA0F03685p
# 28866                                              Shp-1
# 28867                                         Allergin-1
#
#                                                     xref  \
# 0      [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 1                   [[db, dbAc, id, refType, refTypeAc]]
# 2      [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 3      [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 4      [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# ...                                                  ...
# 28863  [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 28864  [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 28865  [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 28866  [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
# 28867  [[db, dbAc, id, refType, refTypeAc], [db, dbAc...
#
#       interactor_type_fullname interactor_type_short_label  \
# 0                      protein
# 1                      protein
# 2                      protein
# 3                      protein
# 4                      protein
# ...                        ...                         ...
# 28863                  protein
# 28864                  protein
# 28865                  protein
# 28866                  protein
# 28867                  protein
#
#                        interactor_type_xref organism_ncbi_tax_id  \
# 0      [[refTypeAc, refType, id, dbAc, db]]                10090
# 1      [[refTypeAc, refType, id, dbAc, db]]                10090
# 2      [[refTypeAc, refType, id, dbAc, db]]                 9606
# 3      [[refTypeAc, refType, id, dbAc, db]]                83333
# 4      [[refTypeAc, refType, id, dbAc, db]]                83333
# ...                                     ...                  ...
# 28863  [[refTypeAc, refType, id, dbAc, db]]               284590
# 28864  [[refTypeAc, refType, id, dbAc, db]]               284590
# 28865  [[refTypeAc, refType, id, dbAc, db]]               284590
# 28866  [[refTypeAc, refType, id, dbAc, db]]                10116
# 28867  [[refTypeAc, refType, id, dbAc, db]]                10090
#
#                    organism_short_label organism_fullname
# 0                          Mus musculus       house mouse
# 1                          Mus musculus       house mouse
# 2                          Homo sapiens             Human
# 3                  Escherichia coli K12
# 4                  Escherichia coli K12
# ...                                 ...               ...
# 28863  Kluyveromyces lactis NRRL Y-1140
# 28864  Kluyveromyces lactis NRRL Y-1140
# 28865  Kluyveromyces lactis NRRL Y-1140
# 28866                 Rattus norvegicus        Norway rat
# 28867                      Mus musculus       house mouse
#
# [28868 rows x 10 columns]

# %%
df = vaex.from_dict(parser.file_dict)
df
# Out:
# #    interactor_id    short_label    fullname                                             xref                                                 interactor_type_fullname    interactor_type_short_label    interactor_type_xref                        organism_ncbi_tax_id    organism_short_label      organism_fullname
# 0    445              Cdkn1b         cyclin-cdk inhibitor p27                             "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-44...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  10090                   Mus musculus              house mouse
# 1    559                             cell division cycle-2-related protein kinase  ERK1   "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-55...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  10090                   Mus musculus              house mouse
# 2    617              CD4            T-cell surface glycoprotein CD4 precursor            "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-61...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  9606                    Homo sapiens              Human
# 3    1025             carB           'Carbamoyl-phosphate synthase large chain (Carba...  "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-10...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  83333                   Escherichia coli K12
# 4    1026             carA           'Carbamoyl-phosphate synthase small chain (Carba...  "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-10...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  83333                   Escherichia coli K12
# ...  ...              ...            ...                                                  ...                                                  ...                         ...                            ...                                         ...                     ...                       ...
# 90   244              ced-3          interleukin-1 beta-converting enzyme homolog CED-3   "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-24...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  6239                    Caenorhabditis elegans
# 91   696              Cyc8p          CYC8 protein                                         "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-69...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  4932                    Saccharomyces cerevisiae  baker's yeast
# 92   665              MIG1           regulatory protein MIG1                              "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-66...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  4932                    Saccharomyces cerevisiae  baker's yeast
# 93   31               CCL5           monocyte chemoattractant cytokine RANTES precursor   "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-31...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  9606                    Homo sapiens              Human
# 94   285              TRADD          'Tumor necrosis factor receptor type 1-associate...  "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-28...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  9606                    Homo sapiens              Human

# %%
df
# Out:
# #    interactor_id    short_label    fullname                                             xref                                                 interactor_type_fullname    interactor_type_short_label    interactor_type_xref                        organism_ncbi_tax_id    organism_short_label      organism_fullname
# 0    445              Cdkn1b         cyclin-cdk inhibitor p27                             "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-44...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  10090                   Mus musculus              house mouse
# 1    559                             cell division cycle-2-related protein kinase  ERK1   "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-55...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  10090                   Mus musculus              house mouse
# 2    617              CD4            T-cell surface glycoprotein CD4 precursor            "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-61...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  9606                    Homo sapiens              Human
# 3    1025             carB           'Carbamoyl-phosphate synthase large chain (Carba...  "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-10...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  83333                   Escherichia coli K12
# 4    1026             carA           'Carbamoyl-phosphate synthase small chain (Carba...  "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-10...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  83333                   Escherichia coli K12
# ...  ...              ...            ...                                                  ...                                                  ...                         ...                            ...                                         ...                     ...                       ...
# 90   244              ced-3          interleukin-1 beta-converting enzyme homolog CED-3   "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-24...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  6239                    Caenorhabditis elegans
# 91   696              Cyc8p          CYC8 protein                                         "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-69...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  4932                    Saccharomyces cerevisiae  baker's yeast
# 92   665              MIG1           regulatory protein MIG1                              "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-66...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  4932                    Saccharomyces cerevisiae  baker's yeast
# 93   31               CCL5           monocyte chemoattractant cytokine RANTES precursor   "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-31...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  9606                    Homo sapiens              Human
# 94   285              TRADD          'Tumor necrosis factor receptor type 1-associate...  "[{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-28...  protein                                                    [['refTypeAc' 'refType' 'id' 'dbAc' 'db']]  9606                    Homo sapiens              Human

# %%
df["xref"].values[0]
# Out:
# [{'db': 'dip', 'dbAc': 'MI:0465', 'id': 'DIP-445N', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#  {'db': 'uniprot knowledge base', 'dbAc': 'MI:0486', 'id': 'P46414', 'refType': 'identity', 'refTypeAc': 'MI:0356'},
#  {'db': 'entrez gene/locuslink', 'dbAc': 'MI:0477', 'id': '12576', 'refType': 'gene product', 'refTypeAc': 'MI:0251'}]
